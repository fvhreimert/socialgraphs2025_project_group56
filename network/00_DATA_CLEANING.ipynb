# %%
import json
import re

# %% [markdown]
# # DATA LOADING

# %%
file_path = '../data/mushroom_data_merged.json'


with open(file_path, 'r') as f:
    data = json.load(f)

# %% [markdown]
# # OVERVIEW

# %%
# Print number of entries
print(f"Number of entries in the dataset: {len(data)}")

# Print all unique keys that exist in the dataset
unique_keys = set()
for entry in data:
    unique_keys.update(entry.keys())
print(f"Unique keys in the dataset: {unique_keys}")

# See all unique keys that exist inside the mycomorphbox key
mycomorphbox_keys = set()
for entry in data:
    if 'mycomorphbox' in entry:
        mycomorphbox_keys.update(entry['mycomorphbox'].keys())
print(f"Unique keys in 'mycomorphbox': {mycomorphbox_keys}")
# Out:
# Number of entries in the dataset: 1161
# Unique keys in the dataset: {'id', 'taxonomy', 'wiki_links', 'views_all_time', 'speciesbox', 'article', 'mycomorphbox', 'mushroom', 'text'}
# Unique keys in 'mycomorphbox': {'name', 'hymeniumType', 'sporePrintColor', 'whichGills', 'stipeCharacter', 'howEdible', 'ecologicalType', 'capShape'}

# %%
morphology_attributes = ['sporePrintColor', 'stipeCharacter', 'name', 'capShape', 'hymeniumType', 'howEdible', 'ecologicalType', 'whichGills']
for i in morphology_attributes:
    attribute_options = set()
    for entry in data:
        if 'mycomorphbox' in entry and i in entry['mycomorphbox']:
            attribute_options.add(entry['mycomorphbox'][i])
    print(f"{len(attribute_options)} Unique options for '{i}': {attribute_options}")
# Out:
# 60 Unique options for 'sporePrintColor': {'Spore print is brown', 'Spore print is purple', 'Spore print is brown\n   to reddish-brown', 'Spore print is cream\n   to white', 'Spore print is white\n   to cream', None, 'Spore print is yellow\n   to ochre', 'Spore print is purple\n   to brown', 'Spore print is green', 'Spore print is purple-brown', 'Spore print is ochre\n   to brown', 'Spore print is reddish-brown', 'Spore print is brown\n   to purple-brown', 'Spore print is tan', 'Spore print is cream\n   to buff', 'Spore print is salmon\n   to reddish-brown', 'Spore print is salmon', 'Spore print is yellow\n   to buff', 'Spore print is yellow', 'Spore print is olive\n   to brown', 'Spore print is pinkish-brown\n   to reddish-brown', 'Spore print is white', 'Spore print is blackish-brown\n   to black', 'Spore print is yellow\n   to cream', 'Spore print is purple-black', 'Spore print is yellow\n   to olive', 'Spore print is black\n   to brown', 'Spore print is brown\n   to yellow-brown', 'Spore print is white\n   to buff', 'Spore print is white\n   to purple-black', 'Spore print is white\n   to yellow', 'Spore print is blackish-brown\n   to brown', 'Spore print is pink\n   to salmon', 'Spore print is olive-brown', 'Spore print is purple-brown\n   to purple-black', 'Spore print is ochre', 'Spore print is brown\n   to purple', 'Spore print is tan\n   to yellow', 'Spore print is blackish-brown', 'Spore print is brown\n   to blackish-brown', 'Spore print is blackish-brown\n   to purple', 'Spore print is yellow-orange', 'Spore print is white\n   to pink', 'Spore print is buff\n   to pink', 'Spore print is olive', 'Spore print is yellow\n   to white', 'Spore print is cream\n   to yellow', 'Spore print is pink\n   to pinkish-brown', 'Spore print is buff', 'Spore print is pink', 'Spore print is cream\n   to salmon', 'Spore print is yellow-brown', 'Spore print is olive\n   to black', 'Spore print is cream', 'Spore print is pink\n   to brown', 'Spore print is black', 'Spore print is olive\n   to olive-brown', 'Spore print is pinkish-brown', 'Spore print is pink\n   to cream', 'Spore print is yellow-orange\n   to brown'}
# 12 Unique options for 'stipeCharacter': {'Stipe has a cortina', 'Stipe is bare\n   or lacks a stipe', 'Stipe is bare\n   or has a cortina', 'Stipe has a volva', 'Lacks a stipe', 'Stipe has a ring or is bare', 'Stipe has a ring and volva', 'Stipe is bare\n   or has a ring', 'Stipe is bare', 'Lacks a stipe or is bare', None, 'Stipe has a ring'}
# 976 Unique options for 'name': {'Gymnopilus microloxus', 'Cerrena unicolor', 'Psilocybe subcaerulipes', 'Gymnopilus subgeminellus', 'Gymnopilus minutosporus', 'Gymnopilus pallidus', 'Gymnopilus perisporius', 'Helvella elastica', 'Psilocybe pelliculosa', 'Astraeus pteridis', 'Mycena galopus', 'Gymnopilus parrumbalus', 'Rubroboletus rhodoxanthus', 'Cortinarius violaceus', 'Armillaria gallica', 'Psilocybe cyanescens', 'Agaricus subrutilescens', 'Gymnopilus subfulgens', 'Cyathus', 'Amanita excelsa', 'Ganoderma tsugae', 'Russula betularum', 'Panaeolus cinctulus', 'Gymnopilus rigidus', 'Tricholoma atrosquamosum', 'Amanita subvaginata', 'Ramaria stricta', 'Laccaria bicolor', 'Inonotus obliquus', 'Lactarius pyrogalus', 'Galerina sulciceps', 'Agaricus pilatianus', 'Gymnopilus depressus', 'Cantharellus formosus', 'Hericium coralloides', 'Cortinarius orellanus', 'Gymnopilus allantopus', 'Gymnopilus primulinus', 'Astraeus odoratus', 'Suillus viscidus', 'Morchella semilibera', 'Boletus auripes', 'Mycena cinerella', 'Lepiota helveola', 'Gymnopilus ombrophilus', 'Gymnopilus pratensis', 'Phellodon tomentosus', 'Gymnopilus ornatulus', 'Lycoperdon echinatum', 'Trametes versicolor', 'Inocybe salicis', 'Agaricus xanthodermus', 'Amanita citrina', 'Psilocybe weraroa', 'Agaricus impudicus', 'Gymnopilus alpinus', 'Gymnopilus decipiens', 'Russula xerampelina', 'Gymnopilus pusillus', 'Amanita exitialis', 'Gymnopilus viscidus', 'Lactarius vinaceorufescens', 'Gymnopilus avellanus', 'Russula amethystina', 'Hygrophoropsis aurantiaca', 'Psilocybe caerulipes', 'Sarcoscypha dudleyi', 'Omphalotus japonicus', 'Amanita parvipantherina', 'Gomphidius maculatus', 'Gymnopilus fulvellus', 'Lysurus periphragmoides', 'Strobilomyces foveatus', 'Amanita frostiana', 'Gymnopilus foedatus', 'Boletus sensibilis', 'Rubroboletus pulcherrimus', 'Marasmius', 'Gymnopilus cantharelloides', 'Gymnopilus vialis', 'Psilocybe plutonia', 'Omphalotus olivascens', 'Gymnopilus bryophilus', 'Amanita aprica', 'Suillellus amygdalinus', 'Humidicutis marginata', 'Gymnopilus aromaticus', 'Caloboletus calopus', 'Mycena vinacea', 'Geastrum quadrifidum', 'Mycena stylobates', 'Gymnopilus tasmanicus', 'Psilocybe tampanensis', 'Gymnopilus palmicola', 'Leccinellum crocipodium', 'Agaricus crocodilinus', 'Gymnopilus terrestris', 'Gymnopilus praecox', 'Lactarius subflammeus', 'Daldinia concentrica', 'Inocybe aeruginascens', 'Amanita abrupta', 'Thelephora terrestris', 'Auriscalpium vulgare', 'Gymnopilus melleus', 'Psilocybe strictipes', 'Gymnopilus pseudofulgens', 'Gymnopilus purpureonitens', 'Agaricus placomyces', 'Gymnopilus fuscosquamulosus', 'Sparassis crispa', 'Mutinus elegans', 'Boletus rex-veris', 'Mycena renati', 'Cantharellus cibarius', 'Amanita virosiformis', 'Inocybe hystrix', 'Gymnopilus crociphyllus', 'Russula ochroleuca', 'Artomyces pyxidatus', 'Psilocybe azurescens', 'Suillus variegatus', 'Gymnopilus konkinyerius', 'Agaricus hondensis', 'Entoloma murrayi', 'Lactarius pubescens', 'Amanita nivalis', 'Gymnopilus pseudocamerinus', 'Gymnopilus flavidellus', 'Lepiota subincarnata', 'Clathrus baumii', 'Cuphophyllus pratensis', 'Flammulina filiformis', 'Gymnopilus spadiceus', 'Gymnopilus fibrillosipes', 'Panaeolus papilionaceus var. parvisporus', 'Gymnopilus aurantiophyllus', 'Gymnopilus tomentulosus', 'Amanita strobiliformis', 'Omphalotus illudens', 'Macrolepiota mastoidea', 'Clitocybe dealbata', 'Paxillus involutus', 'Suillus bovinus', 'Gymnopilus imperialis', 'Gymnopilus spinulifer', 'Clathrus mauritianus', 'Mycena chlorophos', 'Sarcoscypha coccinea', 'Calocybe gambosa', 'Stereum hirsutum', 'Sarcoscypha occidentalis', 'Gymnopilus aureobrunneus', 'Stropharia aeruginosa', 'Cortinarius mucosus', 'Amanita bisporigera', 'Lyophyllum decastes', 'Clavaria fragilis', 'Armillaria mellea', 'Macrocybe titans', 'Lentinellus cochleatus', 'Verpa conica', 'Phallus hadriani', 'Scleroderma citrinum', 'Gymnopilus hypholomoides', 'Amanita crocea', 'Gymnopilus lutescens', 'Gymnopilus testaceus', 'Echinoderma asperum' ...
# 49 Unique options for 'capShape': {'Cap is conical', 'Cap is conical\n   or convex', 'Cap is flat', 'Cap is ovate\n   or umbonate', 'Cap is convex\n   or flat', 'Cap is umbonate\n   or conical', 'Cap is convex\n   or campanulate', 'No distinct cap or offset', 'Cap is flat\n   or infundibuliform', 'Cap is conical\n   or umbonate', 'Cap is umbonate', 'Cap is infundibuliform', None, 'Cap is offset\n   or convex', 'Cap is ovate', 'No distinct cap', 'Cap is umbilicate', 'Cap is convex\n   or conical', 'Cap is campanulate\n   or conical', 'Cap is umbonate\n   or depressed', 'Cap is ovate\n   or flat', 'Cap is ovate\n   or campanulate', 'Cap is flat\n   or convex', 'Cap is convex', 'Cap is convex\n   or depressed', 'Cap is offset', 'Cap is campanulate', 'Cap is depressed\n   or convex', 'Cap is flat\n   or offset', 'Cap is umbonate\n   or flat', 'Cap is depressed', 'Cap is conical\n   or ovate', 'Cap is convex\n   or infundibuliform', 'Cap is flat\n   or depressed', 'Cap is offset\n   or indistinct', 'Cap is campanulate\n   or umbonate', 'Cap is umbonate\n   or campanulate', 'Cap is convex\n   or umbonate', 'Cap is depressed\n   or infundibuliform', 'Cap is flat\n   or umbonate', 'Cap is convex\n   or offset', 'Cap is convex\n   or umbilicate', 'Cap is campanulate\n   or convex', 'Cap is conical\n   or campanulate', 'Cap is depressed\n   or umbilicate', 'Cap is umbonate\n   or ovate', 'Cap is campanulate\n   or flat', 'Cap is depressed\n   or offset', 'Cap is conical\n   or flat'}
# 31 Unique options for 'hymeniumType': {'Hymenium is emarginate\n   or adnate', 'Hymenium is adnexed\n   or adnate', 'Hymenium is subdecurrent', 'Hymenium is adnexed\n   or sinuate', 'Hymenium is adnate', 'Hymenium is adnate\n   or decurrent', 'Pores on hymenium', None, 'Hymenium attachment is not applicable', 'Teeth on hymenium', 'Hymenium attachment is irregular or not applicable', 'Hymenium is adnate\n   or adnexed', 'Smooth hymenium', 'Hymenium is decurrent\n   or subdecurrent', 'Hymenium is emarginate', 'Hymenium is sinuate', 'Hymenium is adnate\n   or free', 'Hymenium is adnate\n   or seceding', 'Hymenium is adnate\n   or emarginate', 'Hymenium is adnate\n   or sinuate', 'Hymenium is free\n   or adnate', 'Hymenium is seceding', 'Hymenium is adnexed\n   or free', 'Hymenium is free', 'Hymenium is subdecurrent\n   or adnate', 'Hymenium is decurrent', 'Hymenium is adnate\n   or subdecurrent', 'Glebal hymenium', 'Hymenium is free\n   or adnexed', 'Hymenium is decurrent\n   or adnate', 'Hymenium is adnexed'}
# 41 Unique options for 'howEdible': {'Edibility is deadly', 'Edibility is edible or can cause allergic reactions', 'Edibility is edible', 'Edibility is choice or can cause allergic reactions', 'Edibility is unknown', 'Edibility is unknown or inedible', 'Edibility is poisonous or psychoactive', 'Edibility is edible or too hard to eat', 'Edibility is inedible\n   or psychoactive', 'Edibility is not recommended or unknown', None, 'Edibility is choice but not recommended', 'Edibility is poisonous or can cause allergic reactions', 'Edibility is edible but not recommended', 'Edibility is unknown but not recommended', 'Edibility is poisonous', 'Edibility is edible or unknown', 'Edibility is psychoactive or edible', 'Edibility is inedible', 'Edibility is edible, but unpalatable', 'Edibility is inedible\n   or edible', 'Edibility is unknown or deadly', 'Edibility is too hard to eat', 'Edibility is not recommended or edible', 'Edibility is choice or edible', 'Edibility is unknown or poisonous', 'Edibility is not recommended', 'Edibility is poisonous or deadly', 'Edibility is edible or edible, but unpalatable', 'Edibility is inedible\n   or poisonous', 'Edibility is choice or inedible', 'Edibility is edible or poisonous', 'Edibility is edible or inedible', 'Edibility is not recommended or poisonous', 'Edibility is not recommended or edible, but unpalatable', 'Edibility is edible or choice', 'Edibility is psychoactive', 'Edibility is choice', 'Edibility is choice or poisonous', 'Edibility is edible or psychoactive', 'Edibility is not recommended or deadly'}
# 9 Unique options for 'ecologicalType': {'Ecology is saprotrophic', 'Ecology is mycorrhizal or parasitic', 'Ecology is parasitic or saprotrophic', 'Ecology is mycorrhizal or saprotrophic', 'Ecology is saprotrophic or mycorrhizal', 'Ecology is parasitic', None, 'Ecology is saprotrophic or parasitic', 'Ecology is mycorrhizal'}
# 2 Unique options for 'whichGills': {None, 'Gills on hymenium'}

# %%
# Print number of entries that has a 'mycomorphbox' key
mycomorphbox_count = sum(1 for entry in data if 'mycomorphbox' in entry)
print(f"Number of entries with 'mycomorphbox': {mycomorphbox_count}")

# Print number of entries that has each morphology attribute
for i in morphology_attributes:
    count = sum(1 for entry in data if 'mycomorphbox' in entry and i in entry['mycomorphbox'])
    print(f"Number of entries with '{i}': {count}")
# Out:
# Number of entries with 'mycomorphbox': 1101
# Number of entries with 'sporePrintColor': 1101
# Number of entries with 'stipeCharacter': 1101
# Number of entries with 'name': 1101
# Number of entries with 'capShape': 1101
# Number of entries with 'hymeniumType': 1101
# Number of entries with 'howEdible': 1101
# Number of entries with 'ecologicalType': 1101
# Number of entries with 'whichGills': 1101

# %% [markdown]
# # ATTRIBUTE CLEANING

# %%
# We need to clean all the morphology attributes, so we can use the for the network later. We start with sporePrintColor.

attribute = "sporePrintColor"
for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue
    # Remove "Spore print is" from the string
    cleaned_color = value.replace("Spore print is ", "").strip()
    # Remove newline characters
    cleaned_color = cleaned_color.replace("\n", "").strip()

    # Split by comma, -, " to ", " " and keep the list
    cleaned_color = [x.strip() for x in re.split(r',|-| to | ', cleaned_color) if x.strip()]
    data[i]['mycomorphbox'][attribute] = cleaned_color

# %%
# We need to clean all the morphology attributes, so we can use the for the network later. Now we do capShape.
attribute = 'capShape'
for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue

    # Remove "Cap is" from the string
    value = value.replace("Cap is ", "").strip()
    # Remove newline characters
    value = value.replace("\n", "").strip()

    # Remove "or"
    value = value.replace(" or ", "")

    # Split by comma, -, " to ", " " and keep the list
    value = [x.strip() for x in re.split(r',|-| to | ', value) if x.strip()]

    data[i]['mycomorphbox'][attribute] = value

# %%
# We need to clean all the morphology attributes, so we can use the for the network later. Now we do stipeCharacter.

attribute = 'stipeCharacter'
for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue
    value = value.replace("Stipe is ", "").strip()
    value = value.replace("Stipe has a ", "").strip()
    value = value.replace("\n", "").strip()
    value = value.replace("or is", "").strip()
    value = value.replace("and", "").strip()
    value = value.replace("or has a", "").strip()
    value = value.replace("or", "").strip()

    # Remove word and text after "Lacks a"
    value = re.split(r'Lacks a', value)[0].strip()
    value = re.split(r'lacks a', value)[0].strip()

    # Split by comma, -, " to ", " " and keep the list
    value = [x.strip() for x in re.split(r',|-| to | ', value) if x.strip()]

    data[i]['mycomorphbox'][attribute] = value

# %%
# We need to clean all the morphology attributes, so we can use the for the network later. Now we do capShape.
attribute = 'hymeniumType'
for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue

    # Remove "Hymenium is" from the string
    value = value.replace("Hymenium is ", "").strip()
    # Remove "or"
    value = value.replace(" or ", "")

    # Remove "Hymenium attachment is irregularnot applicable"
    value = value.replace("Hymenium attachment is irregularnot applicable", "").strip()
    # Remove "Hymenium attachment is not applicable"
    value = value.replace("Hymenium attachment is not applicable", "").strip()

    # Split by comma, -, " to ", " " and keep the list
    value = [x.strip() for x in re.split(r',|-| to | ', value) if x.strip()]

    data[i]['mycomorphbox'][attribute] = value

# %%
# We need to clean all the morphology attributes, so we can use the for the network later. Now we do capShape.
attribute = 'howEdible'
for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue
    # Remove "Edibility is" from the string
    value = value.replace("Edibility is ", "").strip()
    # Remove "unknown"
    value = value.replace("unknown", "").strip()
    # Remove "or"
    # Replace edible with " edible " but not in words like inedible
    value = re.sub(r'(?<!in)(edible)', ' edible ', value)
    # Replace poisonous with " poisonous "
    value = value.replace("poisonous", " poisonous ")
    # Replace psychoactive with " psychoactive "
    value = value.replace("psychoactive", " psychoactive ")
    # Remove can cause
    value = re.sub(r'can cause [a-zA-Z ,]+', '', value)

    # Replace "not recommended" with "not_recommended"
    value = value.replace("not recommended", "not_recommended")

    # Replace "choice" with " choice "
    value = value.replace("choice", " choice ")

    # Replace too hard to eat with "too_hard_to_eat"
    value = value.replace("too hard to eat", "too_hard_to_eat")

    # Remove "but"
    value = value.replace("or", "")
    value = value.replace("but", "")
    
    # Split by comma, -, " to ", " " and keep the list
    value = [x.strip() for x in re.split(r',|-| to | ', value) if x.strip()]

    data[i]['mycomorphbox'][attribute] = value

# %%
# We need to clean all the morphology attributes, so we can use the for the network later. Now we do capShape.
attribute = 'whichGills'
for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue
    data[i]['mycomorphbox'][attribute] = [value]

# %%
attribute = "ecologicalType"

for i in range(len(data)):
    if 'mycomorphbox' not in data[i]:
        continue
    value = data[i]['mycomorphbox'][attribute]
    if value is None:
        data[i]['mycomorphbox'][attribute] = []
        continue
    # Remove "Ecology is" from the string
    value = value.replace("Ecology is ", "").strip()

    # Remove "or"
    value = value.replace(" or ", "")

    # Split by comma, -, " to ", " " and keep the list
    value = [x.strip() for x in re.split(r',|-| to | ', value) if x.strip()]
    data[i]['mycomorphbox'][attribute] = value

# %%
attribute = "conservation_status"

for i in range(len(data)):
    if 'speciesbox' not in data[i]:
        continue
    value = data[i]['speciesbox'][attribute]
    if value is None:
        data[i]['speciesbox'][attribute] = []
        continue
    
    # Split by comma, -, " to ", " " and keep the list
    value = [x.strip() for x in re.split(r',|-| to | ', value) if x.strip()]
    data[i]['speciesbox'][attribute] = value

# %% [markdown]
# # NETWORK CREATION

# %%
import networkx as nx
from itertools import combinations
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Make a network using networkx, where each node is mushroom from the dataset.
# The following attributes from the data should be added to each node:
# ["mycomorphbox"]["sporePrintColor"]
# ["mycomorphbox"]["stipeCharacter"]
# ["mycomorphbox"]["capShape"]
# ["mycomorphbox"]["hymeniumType"]
# ["mycomorphbox"]["ecologicalType"]
# ["mycomorphbox"]["whichGills"]
# ["speciesbox"]["conservation_status"]
# ["mushroom"]
# ["id"]
# ["views_all_time"]
# ["article"]
# ["speciesbox"]["image"]
# Also include taxonomic information for the purposes of future work.

G = nx.Graph()

for entry in data:
    if "mycomorphbox" not in entry or "speciesbox" not in entry:
        continue
    node_id = entry.get("id")

    # Extract attributes safely
    myco = entry.get("mycomorphbox", {})
    speciesbox = entry.get("speciesbox", {})
    taxonomy = entry.get("taxonomy", {})

    attrs = {
        "mushroom": entry.get("mushroom"),
        "id": node_id,
        "views_all_time": entry.get("views_all_time"),
        "article": entry.get("article"),
        "sporePrintColor": myco.get("sporePrintColor"),
        "howEdible": myco.get("howEdible"),
        "stipeCharacter": myco.get("stipeCharacter"),
        "capShape": myco.get("capShape"),
        "hymeniumType": myco.get("hymeniumType"),
        "ecologicalType": myco.get("ecologicalType"),
        "whichGills": myco.get("whichGills"),
        "conservation_status": speciesbox.get("conservation_status"),
        "image": speciesbox.get("image"),
        "Genus": taxonomy.get("Genus"),
        "Family": taxonomy.get("Family"),
        "Order": taxonomy.get("Order"),
        "Class": taxonomy.get("Class"),
        "Division": taxonomy.get("Division"),
        "Species": taxonomy.get("Species"),
        "text": entry.get("text"), 
        "article": entry.get("article"),
        "wikilinks": entry.get("wiki_links")
    }

    G.add_node(node_id, **attrs)

# Example: inspect attributes for one node
print(G.nodes[data[0]["id"]])
# Out:
# {'mushroom': 'Russula maculata', 'id': 1, 'views_all_time': 9897, 'article': 'https://en.wikipedia.org/wiki/Russula_maculata', 'sporePrintColor': ['yellow', 'ochre'], 'howEdible': [], 'stipeCharacter': ['bare'], 'capShape': ['convex', 'depressed'], 'hymeniumType': ['adnexed', 'free'], 'ecologicalType': ['mycorrhizal'], 'whichGills': ['Gills on hymenium'], 'conservation_status': [], 'image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/82/1996-02-15_Russula_maculata_Qu%C3%A9l._%26_Roze_117.jpg/250px-1996-02-15_Russula_maculata_Qu%C3%A9l._%26_Roze_117.jpg', 'Genus': 'Russula', 'Family': 'Russulaceae', 'Order': 'Russulales', 'Class': 'Agaricomycetes', 'Division': 'Basidiomycota', 'Species': 'R.\xa0maculata', 'text': 'Russula maculata is a species of mushroom in the genus Russula . [ 1 ] Its cap ranges from 4–10 centimetres ( 1 + 1 ⁄ 2 –4\xa0in) wide, with hues varying from whitish to red. [ 2 ] It is difficult to distinguish reliably and its edibility is unknown. [ 2 ]\nThis Russulales -related article is a stub . You can help Wikipedia by expanding it .', 'wikilinks': [{'url': 'https://en.wikipedia.org/wiki/Taxonomy_(biology)', 'text': 'Scientific classification'}, {'url': 'https://en.wikipedia.org/wiki/Fungus', 'text': 'Fungi'}, {'url': 'https://en.wikipedia.org/wiki/Basidiomycota', 'text': 'Basidiomycota'}, {'url': 'https://en.wikipedia.org/wiki/Agaricomycetes', 'text': 'Agaricomycetes'}, {'url': 'https://en.wikipedia.org/wiki/Russulales', 'text': 'Russulales'}, {'url': 'https://en.wikipedia.org/wiki/Russulaceae', 'text': 'Russulaceae'}, {'url': 'https://en.wikipedia.org/wiki/Russula', 'text': 'Russula'}, {'url': 'https://en.wikipedia.org/wiki/Binomial_nomenclature', 'text': 'Binomial name'}, {'url': 'https://en.wikipedia.org/wiki/Qu%C3%A9l.', 'text': 'Quél.'}, {'url': 'https://en.wikipedia.org/wiki/Mushroom', 'text': 'mushroom'}, {'url': 'https://en.wikipedia.org/wiki/David_Arora', 'text': 'Arora, David'}, {'url': 'https://en.wikipedia.org/wiki/Ten_Speed_Press', 'text': 'Ten Speed Press'}, {'url': 'https://en.wikipedia.org/wiki/ISBN_(identifier)', 'text': 'ISBN'}, {'url': 'https://en.wikipedia.org/wiki/Index_Fungorum', 'text': 'Index Fungorum'}, {'url': 'https://en.wikipedia.org/wiki/Mycology', 'text': 'Mycological characteristics'}, {'url': 'https://en.wikipedia.org/wiki/Lamella_(mycology)', 'text': 'Gills'}, {'url': 'https://en.wikipedia.org/wiki/Hymenium', 'text': 'hymenium'}, {'url': 'https://en.wikipedia.org/wiki/Pileus_(mycology)', 'text': 'Cap'}, {'url': 'https://en.wikipedia.org/wiki/Stipe_(mycology)', 'text': 'Stipe'}, {'url': 'https://en.wikipedia.org/wiki/Spore_print', 'text': 'Spore print'}, {'url': 'https://en.wikipedia.org/wiki/Mycorrhizal', 'text': 'mycorrhizal'}, {'url': 'https://en.wikipedia.org/wiki/Mushroom_poisoning', 'text': 'unknown'}, {'url': 'https://en.wikipedia.org/wiki/Wikidata', 'text': 'Wikidata'}, {'url': 'https://en.wikipedia.org/wiki/Catalogue_of_Life', 'text': 'CoL'}, {'url': 'https://en.wikipedia.org/wiki/Encyclopedia_of_Life', 'text': 'EoL'}, {'url': 'https://en.wikipedia.org/wiki/EPPO_Code', 'text': 'EPPO'}, {'url': 'https://en.wikipedia.org/wiki/Global_Biodiversity_Information_Facility', 'text': 'GBIF'}, {'url': 'https://en.wikipedia.org/wiki/INaturalist', 'text': 'iNaturalist'}, {'url': 'https://en.wikipedia.org/wiki/Interim_Register_of_Marine_and_Nonmarine_Genera', 'text': 'IRMNG'}, {'url': 'https://en.wikipedia.org/wiki/MycoBank', 'text': 'MycoBank'}, {'url': 'https://en.wikipedia.org/wiki/NatureServe', 'text': 'NatureServe'}, {'url': 'https://en.wikipedia.org/wiki/National_Biodiversity_Network', 'text': 'NBN'}, {'url': 'https://en.wikipedia.org/wiki/National_Center_for_Biotechnology_Information', 'text': 'NCBI'}, {'url': 'https://en.wikipedia.org/wiki/Observation.org', 'text': 'Observation.org'}, {'url': 'https://en.wikipedia.org/wiki/Open_Tree_of_Life', 'text': 'Open Tree of Life'}]}

# %%
import pickle
with open('mushroom_network_no_edges.pkl', 'wb') as f:
    pickle.dump(G, f)
